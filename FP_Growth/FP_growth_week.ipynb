# %%
# !pip install "dask[complete]"
# !pip install mlxtend
# Out:
# Collecting dask[complete]
#   Downloading dask-2024.5.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (2024.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (24.0)
# Collecting partd>=1.2.0 (from dask[complete])
#   Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (0.12.1)
# Collecting importlib-metadata>=4.13.0 (from dask[complete])
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (16.1.0)
# Collecting pyarrow-hotfix (from dask[complete])
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting lz4>=4.3.2 (from dask[complete])
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[complete]) (3.19.1)
# Collecting locket (from partd>=1.2.0->dask[complete])
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow>=7.0->dask[complete]) (1.25.2)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (2.0.3)
# Collecting dask-expr<1.2,>=1.1 (from dask[complete])
#   Downloading dask_expr-1.1.2-py3-none-any.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.5/205.5 kB 12.3 MB/s eta 0:00:00
# Collecting bokeh>=2.4.2 (from dask[complete])
#   Downloading bokeh-3.4.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 44.6 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from dask[complete]) (3.1.4)
# Collecting distributed==2024.5.2 (from dask[complete])
#   Downloading distributed-2024.5.2-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.4 MB/s eta 0:00:00
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed==2024.5.2->dask[complete]) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed==2024.5.2->dask[complete]) (5.9.5)
# Collecting sortedcontainers>=2.0.5 (from distributed==2024.5.2->dask[complete])
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting tblib>=1.6.0 (from distributed==2024.5.2->dask[complete])
#   Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed==2024.5.2->dask[complete]) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed==2024.5.2->dask[complete]) (2.0.7)
# Collecting zict>=3.0.0 (from distributed==2024.5.2->dask[complete])
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->dask[complete]) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->dask[complete]) (10.3.0)
# Collecting xyzservices>=2021.09.1 (from bokeh>=2.4.2->dask[complete])
#   Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->dask[complete]) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->dask[complete]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->dask[complete]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3->dask[complete]) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3->dask[complete]) (1.16.0)
# Installing collected packages: sortedcontainers, zict, xyzservices, tblib, pyarrow-hotfix, lz4, locket, importlib-metadata, partd, dask, bokeh, distributed, dask-expr
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
# Successfully installed bokeh-3.4.1 dask-2024.5.2 dask-expr-1.1.2 distributed-2024.5.2 importlib-metadata-7.1.0 locket-1.0.0 lz4-4.3.3 partd-1.4.2 pyarrow-hotfix-0.6 sortedcontainers-2.4.0 tblib-3.0.0 xyzservices-2024.6.0 zict-3.0.0
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.25.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from pathlib import Path
import os
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.preprocessing import TransactionEncoder
import dask.dataframe as dd
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_colwidth', None)

# %%
data_dir = Path('/content/drive/MyDrive/Data_hasking_without_banker_account')
ddf = dd.read_parquet(str(data_dir / '*.parquet'))
ddf
# Out:
# Dask DataFrame Structure:
#                 CUST_CUSTNO ACC_BUSINESSTYPE ACC_ACCNO ACC_BUSINESSNO ACC_CURRENCYISO BUSINESSNO_TRANS FK_CURRENCY   AMOUNT AMOUNTORIG BRANCH_OFFICE CONTRA_ACCNO CONTRA_ZIP CONTRA_NAME   CSHYN REASON1 REASON2 REASON4 TR_FLAG_01 ANALYTICAL_TRANS_CODE TR_SP_01 TR_SP_02 TR_SP_03 TR_SP_04 TR_SP_05 TR_SP_10 VALUEDATE
# npartitions=184
#                      string           string    string         string          string           string      string  float64    float64        string       string     string      string  string  string  string  string     string                string   string   string   string   string   string  float64    string
#                         ...              ...       ...            ...             ...              ...         ...      ...        ...           ...          ...        ...         ...     ...     ...     ...     ...        ...                   ...      ...      ...      ...      ...      ...      ...       ...
# ...                     ...              ...       ...            ...             ...              ...         ...      ...        ...           ...          ...        ...         ...     ...     ...     ...     ...        ...                   ...      ...      ...      ...      ...      ...      ...       ...
#                         ...              ...       ...            ...             ...              ...         ...      ...        ...           ...          ...        ...         ...     ...     ...     ...     ...        ...                   ...      ...      ...      ...      ...      ...      ...       ...
#                         ...              ...       ...            ...             ...              ...         ...      ...        ...           ...          ...        ...         ...     ...     ...     ...     ...        ...                   ...      ...      ...      ...      ...      ...      ...       ...
# Dask Name: read_parquet, 1 expression
# Expr=ReadParquetFSSpec(99666ac)

# %%
df=ddf.compute()

# %%
# Optimize missing value handling
df = df.dropna(thresh=len(df) * 0.5, axis=1)  # Drop columns with more than 50% missing values
df = df.fillna(df.mode().iloc[0])  # Fill missing values with mode for string columns

# Identify numeric columns
numeric_cols = df.select_dtypes(include='number').columns

# Fill missing values with median for numeric columns only
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
df.isnull().sum()
# Out:
# CUST_CUSTNO              0
# ACC_BUSINESSTYPE         0
# ACC_ACCNO                0
# ACC_BUSINESSNO           0
# ACC_CURRENCYISO          0
# BUSINESSNO_TRANS         0
# FK_CURRENCY              0
# AMOUNT                   0
# AMOUNTORIG               0
# BRANCH_OFFICE            0
# CONTRA_ACCNO             0
# CONTRA_ZIP               0
# CONTRA_NAME              0
# CSHYN                    0
# REASON1                  0
# REASON2                  0
# TR_FLAG_01               0
# ANALYTICAL_TRANS_CODE    0
# TR_SP_01                 0
# TR_SP_02                 0
# TR_SP_03                 0
# TR_SP_04                 0
# TR_SP_05                 0
# VALUEDATE                0
# dtype: int64

# %%
# Convert the VALUEDATE column to datetime format
df['VALUEDATE'] = dd.to_datetime(df['VALUEDATE'])
# Define the start and end dates for the desired week
start_date = '2024-01-01'
end_date = '2024-01-07'

# Filter data for the specified week
filtered_data= df[(df['VALUEDATE'] >= start_date) & (df['VALUEDATE'] <= end_date)]

# %%
filtered_data
# Out:
#                                                               CUST_CUSTNO  \
# 907      2bdb75e6139a7717939d04a1ef7b8a7e17fe3261064a309c02aac70c7a447709
# 1110     39f2cdbe919da465def1ccfd021faaa991024ec0be217f36709ec916b244fc28
# 1482     9d3d2ff5e7b1968a85094ce265620d44959f254a442d71db974d2bf8c38779c6
# 1716     8f9f3bd056ba38251221307d62eb4ed3afbbf1ab470125e406d979b48797f563
# 1741     6fb16bee4249b2780b0693d73affb53ba8f12808982b3af2252b68c2ef904e4e
# ...                                                                   ...
# 1030184  b7aec93092f3ab6984109b097d6db4ecb33ff9f47f432cff895832a81b439d32
# 1030228  34e0bbcf928bde2bdeb733f252737247ca756a99f2af30f51c53ed7f77322d0b
# 1030686  61fd9631094000c5107a1922d34c9042ee8d8a8ec3b096371236bf344207548f
# 1030838  9ebbc0a429995b5a4459b8bf4e90e97a3af741e1fccc199b7839a3618785241f
# 1030900  bfff88f6a605e7b6087797c04442f91412213b300ed94d17587f1e518e906a70
#
#         ACC_BUSINESSTYPE  \
# 907                 CASA
# 1110                CASA
# 1482                CASA
# 1716                CASA
# 1741                CASA
# ...                  ...
# 1030184             CASA
# 1030228             CASA
# 1030686             CASA
# 1030838             CASA
# 1030900             CASA
#
#                                                                 ACC_ACCNO  \
# 907      c60feae21e6d3a79d1b9dca82edf74b97b9e0bd93c461c51b092b7bdbfe8777d
# 1110     bc971c77455ea3bfaafb3ed1720a350a0c41b558fb03af1d6693bc9e0c9a58a9
# 1482     0214eb9bc6f571fe82ff614133a9b39dfcff04fd59b4e976f8f04868facae0fd
# 1716     6c14af8e55eb35b7dd6e8ace87ad61e9c943d9a477e1982d0acabf40e21b8855
# 1741     1dc5f75ff8be52bde53170a1a03da13deb2336c6cd4a2e8c2db94cd9935e399e
# ...                                                                   ...
# 1030184  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030228  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030686  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030838  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030900  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
#
#                                                            ACC_BUSINESSNO  \
# 907      0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1110     0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1482     0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1716     0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1741     0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# ...                                                                   ...
# 1030184  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030228  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030686  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030838  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
# 1030900  0553d33b8bbc8e3a944ff438a51a17cfb38fd0241667af98b6834685cc487ee6
#
#         ACC_CURRENCYISO  BUSINESSNO_TRANS FK_CURRENCY    AMOUNT  AMOUNTORIG  \
# 907                 VND   202308011167253         VND   -500.00     -500.00
# 1110                VND   202308011205083         VND   1500.00     1500.00
# 1482                VND   202308011176487         VND   -247.00     -247.00
# 1716                VND   202308011219515         VND   2560.52     2560.52
# 1741                VND   202308011169837         VND -10000.00   -10000.00
# ...                 ...               ...         ...       ...         ...
# 1030184             VND  2024013041174361         VND     20.00       20.00
# 1030228             VND  2024013041119751         VND -15000.00   -15000.00
# 1030686             VND  2024013041119762         VND -20000.00   -20000.00
# 1030838             VND  2024013041175249         VND   7500.00     7500.00
# 1030900             VND  2024013041171662         VND  20365.97    20365.97
#
#         BRANCH_OFFICE  ...                      REASON1  \
# 907            110000  ...  DOAN THI KIM OANH CHUYEN KH
# 1110           110000  ...  Thuong thanh lap cty Mr DO
# 1482           110000  ...  TRAN NGUYEN HUNG  CHUYEN KH
# 1716           110000  ...  XXXXXXXX-CTY TNHH LIEN CAU
# 1741           110000  ...               QUANG MINH VAY
# ...               ...  ...                          ...
# 1030184        110000  ...  AU VU HOANG CHUYEN KHOAN AU
# 1030228        110000  ...               Vk sam Tet nhe
# 1030686        110000  ...  VO THI THU HUYEN  CHUYEN KH
# 1030838        110300  ...  CTY THAN MONG DUONG BO SUNG
# 1030900        110300  ...  CONG TY CP THAN MONG DUONG-
#
#                              REASON2 TR_FLAG_01 ANALYTICAL_TRANS_CODE  \
# 907                  OAN VU THU HIEN          N                   1|1
# 1110                       TRONG MAO          N                   1|2
# 1482                 OAN VU THI HANG          N                   1|1
# 1716     VN - (CKRmNo: XXXXXXXXXXXXX          N                 21|45
# 1741                               N          N                   1|1
# ...                              ...        ...                   ...
# 1030184                     VU HOANG          N                   1|2
# 1030228                            N          N                   1|1
# 1030686       OAN NGUYEN THI KIM ANH          N                   1|1
# 1030838   TIEN LUONG THANG X NAM XXX          N                   1|2
# 1030900  VINACOMIN PHAN PHOI TIEN LU          N                   1|2
#
#                                                                  TR_SP_01  \
# 907      a390b60d34d64407a224af176bb5f2fd44994e48b7a6e469edbf468b2dab4e63
# 1110     e7912596f20db264bbe7b42e86f6cbf9530933a500eaabff63813bdbea2cc71b
# 1482     7e85fd8173f58d5eca0b549f62b450e2cc629dd129956e4375152f2c71db61f2
# 1716     c2158f0937b6db07cbfa88e85c784c23c0ccf9ab42793ea9741e60699f414e13
# 1741     f2cffcbcc2699d6d4ed05b5ed35ccda52d264543c11879cd834e3000122d825c
# ...                                                                   ...
# 1030184  c012940028b93766a4c4088f905f17911c6ae466ce394c6266431bff06208108
# 1030228  2b36a9ae3bfe1ad4336600851ba3d8f12b1752a7a0b203c72e15c039664bd049
# 1030686  d73c17d316d8faa727e8ca06cb642de6e79e41b64576718a947806bea0022db5
# 1030838  19e6683a4e4917eae1be8d7d69d65076b15b33a24731447649d51c0557ef8dbe
# 1030900  99dff521be5a64fe066ba54e26eb2bbf79693028bc2817aee69af005547e2688
#
#         TR_SP_02       TR_SP_03 TR_SP_04                             TR_SP_05  \
# 907          MOB     HOI SO SHB       A2                          VU THU HIEN
# 1110         MOB     HOI SO SHB       A2                        TRINH THI NGA
# 1482         MOB     HOI SO SHB       A2                          VU THI HANG
# 1716         STP     HOI SO SHB       LP                            CITAD SHB
# 1741         MOB     HOI SO SHB       A2                        VI VAN NHUONG
# ...          ...            ...      ...                                  ...
# 1030184      MOB     HOI SO SHB       A2                          AU VU HOANG
# 1030228      MOB     HOI SO SHB       A2                      NGUYEN THI THOM
# 1030686      MOB     HOI SO SHB       A2                   NGUYEN THI KIM ANH
# 1030838      BLK  CN QUANG NINH       A2  CASA TRUNG GIAN CHUYEN TIEN THEO LO
# 1030900      BLK  CN QUANG NINH       A2  CASA TRUNG GIAN CHUYEN TIEN THEO LO
#
#          VALUEDATE
# 907     2024-01-07
# 1110    2024-01-05
# 1482    2024-01-05
# 1716    2024-01-05
# 1741    2024-01-05
# ...            ...
# 1030184 2024-01-05
# 1030228 2024-01-03
# 1030686 2024-01-01
# 1030838 2024-01-02
# 1030900 2024-01-03
#
# [420137 rows x 24 columns]

# %%
# Convert categorical columns to categorical data type
categorical_cols = filtered_data.select_dtypes(include=['string']).columns
for col in categorical_cols:
    filtered_data[col] = filtered_data[col].astype('category')

# %%
categorical_cols
# Out:
# Index(['CUST_CUSTNO', 'ACC_BUSINESSTYPE', 'ACC_ACCNO', 'ACC_BUSINESSNO',
#        'ACC_CURRENCYISO', 'BUSINESSNO_TRANS', 'FK_CURRENCY', 'BRANCH_OFFICE',
#        'CONTRA_ACCNO', 'CONTRA_ZIP', 'CONTRA_NAME', 'CSHYN', 'REASON1',
#        'REASON2', 'TR_FLAG_01', 'ANALYTICAL_TRANS_CODE', 'TR_SP_01',
#        'TR_SP_02', 'TR_SP_03', 'TR_SP_04', 'TR_SP_05'],
#       dtype='object')

# %%
# Label encode string columns
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
for column in filtered_data.select_dtypes(include=['category']).columns:
    le = LabelEncoder()
    filtered_data[column] = le.fit_transform(filtered_data[column])
    label_encoders[column] = le

# %%
filtered_data
# Out:
#          CUST_CUSTNO  ACC_BUSINESSTYPE  ACC_ACCNO  ACC_BUSINESSNO  \
# 907            23979                 0     115012               0
# 1110           31553                 0     109609               0
# 1482           85777                 0       1186               0
# 1716           78513                 0      62818               0
# 1741           61121                 0      17436               0
# ...              ...               ...        ...             ...
# 1030184       100258                 0       3103               0
# 1030228        28847                 0       3103               0
# 1030686        53541                 0       3103               0
# 1030838        86573                 0       3103               0
# 1030900       104915                 0       3103               0
#
#          ACC_CURRENCYISO  BUSINESSNO_TRANS  FK_CURRENCY    AMOUNT  AMOUNTORIG  \
# 907                   10               201           10   -500.00     -500.00
# 1110                  10              1523           10   1500.00     1500.00
# 1482                  10               535           10   -247.00     -247.00
# 1716                  10              2001           10   2560.52     2560.52
# 1741                  10               309           10 -10000.00   -10000.00
# ...                  ...               ...          ...       ...         ...
# 1030184               10            419626           10     20.00       20.00
# 1030228               10            417771           10 -15000.00   -15000.00
# 1030686               10            417773           10 -20000.00   -20000.00
# 1030838               10            419656           10   7500.00     7500.00
# 1030900               10            419530           10  20365.97    20365.97
#
#          BRANCH_OFFICE  ...  REASON1  REASON2  TR_FLAG_01  \
# 907                  0  ...    27470   127124           0
# 1110                 0  ...   108081   137123           0
# 1482                 0  ...    98558   127005           0
# 1716                 0  ...   126146   143207           0
# 1741                 0  ...    88719    89235           0
# ...                ...  ...      ...      ...         ...
# 1030184              0  ...     2189    27662           0
# 1030228              0  ...   117944    89235           0
# 1030686              0  ...   112284   123174           0
# 1030838             19  ...    15935    23988           0
# 1030900             19  ...    14003   143158           0
#
#          ANALYTICAL_TRANS_CODE  TR_SP_01  TR_SP_02  TR_SP_03  TR_SP_04  \
# 907                          0    263550         7        60         0
# 1110                         1    373173         7        60         0
# 1482                         0    203888         7        60         0
# 1716                         4    312975        11        60         2
# 1741                         0    391069         7        60         0
# ...                        ...       ...       ...       ...       ...
# 1030184                      1    309692         7        60         0
# 1030228                      0     69807         7        60         0
# 1030686                      0    346941         7        60         0
# 1030838                      1     41809         1        42         0
# 1030900                      1    247931         1        42         0
#
#          TR_SP_05  VALUEDATE
# 907         77114 2024-01-07
# 1110        70322 2024-01-05
# 1482        76581 2024-01-05
# 1716         5259 2024-01-05
# 1741        73443 2024-01-05
# ...           ...        ...
# 1030184       183 2024-01-05
# 1030228     50541 2024-01-03
# 1030686     49367 2024-01-01
# 1030838      4092 2024-01-02
# 1030900      4092 2024-01-03
#
# [420137 rows x 24 columns]

# %%
# Apply the FP-growth algorithm
frequent_itemsets = fpgrowth(filtered_data, min_support=0.99, use_colnames=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-ebc774d0ca1b> in <cell line: 2>()
#       1 # Apply the FP-growth algorithm
# ----> 2 frequent_itemsets = fpgrowth(filtered_data, min_support=0.99, use_colnames=True)
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpgrowth.py in fpgrowth(df, min_support, use_colnames, max_len, verbose)
#      71
#      72     """
# ---> 73     fpc.valid_input_check(df)
#      74
#      75     if min_support <= 0.0:
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py in valid_input_check(df)
#     129                 " are True, False, 0, 1. Found value %s" % (val)
#     130             )
# --> 131             raise ValueError(s)
#     132
#     133
#
# ValueError: The allowed values for a DataFrame are True, False, 0, 1. Found value 23979

# %% [markdown]
# **convert the data format from numeric to binary**

# %%
# Create a binary representation of the data
frequent_itemsets = fpgrowth(filtered_data.applymap(lambda x: 1 if x else 0), min_support=0.01, use_colnames=True)
# Adjust min_support as needed, likely much lower than 0.99 given binary representation

# %%
frequent_itemsets
# Out:
#           support  \
# 0        1.000000
# 1        0.999998
# 2        0.999998
# 3        0.999998
# 4        0.999998
# ...           ...
# 1179642  0.013665
# 1179643  0.013665
# 1179644  0.013665
# 1179645  0.013665
# 1179646  0.013665
#
#                                                                                                                                                                                                                                                          itemsets
# 0                                                                                                                                                                                                                                                     (VALUEDATE)
# 1                                                                                                                                                                                                                                                      (TR_SP_05)
# 2                                                                                                                                                                                                                                                  (CONTRA_ACCNO)
# 3                                                                                                                                                                                                                                                       (REASON1)
# 4                                                                                                                                                                                                                                                      (TR_SP_01)
# ...                                                                                                                                                                                                                                                           ...
# 1179642                   (TR_SP_03, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179643               (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179644            (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179645            (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179646  (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
#
# [1179647 rows x 2 columns]

# %%
# Create a binary representation of the data
frequent_itemsets = fpgrowth(filtered_data.applymap(lambda x: 1 if x else 0), min_support=0.99, use_colnames=True)

# %%
frequent_itemsets
# Out:
#         support  \
# 0      1.000000
# 1      0.999998
# 2      0.999998
# 3      0.999998
# 4      0.999998
# ...         ...
# 48634  0.990008
# 48635  0.990010
# 48636  0.990008
# 48637  0.990008
# 48638  0.990008
#
#                                                                                                                                                    itemsets
# 0                                                                                                                                               (VALUEDATE)
# 1                                                                                                                                                (TR_SP_05)
# 2                                                                                                                                                 (REASON1)
# 3                                                                                                                                                (TR_SP_01)
# 4                                                                                                                                        (BUSINESSNO_TRANS)
# ...                                                                                                                                                     ...
# 48634                     (CONTRA_ACCNO, TR_SP_05, TR_SP_01, BUSINESSNO_TRANS, ACC_ACCNO, AMOUNTORIG, CUST_CUSTNO, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 48635                    (CONTRA_ACCNO, VALUEDATE, TR_SP_05, TR_SP_01, ACC_ACCNO, AMOUNTORIG, CUST_CUSTNO, AMOUNT, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 48636          (CONTRA_ACCNO, VALUEDATE, TR_SP_05, TR_SP_01, BUSINESSNO_TRANS, ACC_ACCNO, AMOUNTORIG, CUST_CUSTNO, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 48637             (CONTRA_ACCNO, TR_SP_05, TR_SP_01, BUSINESSNO_TRANS, ACC_ACCNO, AMOUNTORIG, CUST_CUSTNO, AMOUNT, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 48638  (CONTRA_ACCNO, VALUEDATE, TR_SP_05, TR_SP_01, BUSINESSNO_TRANS, ACC_ACCNO, AMOUNTORIG, CUST_CUSTNO, AMOUNT, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
#
# [48639 rows x 2 columns]
# Warning: total number of rows (48639) exceeds max_rows (20000). Limiting to first (20000) rows.
# Warning: total number of rows (48639) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
from mlxtend.frequent_patterns import association_rules

# Define the minimum confidence level
min_confidence = 1

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)

# %%
# Display the association rules
rules
# Out:
#                                                                                                                                          antecedents  \
# 0                                                                                                                                         (TR_SP_05)
# 1                                                                                                                                          (REASON1)
# 2                                                                                                                                (TR_SP_05, REASON1)
# 3                                                                                                                                         (TR_SP_01)
# 4                                                                                                                                (REASON1, TR_SP_01)
# ...                                                                                                                                              ...
# 107258  (CONTRA_ACCNO, VALUEDATE, TR_SP_05, BUSINESSNO_TRANS, ACC_ACCNO, AMOUNTORIG, TR_SP_01, CUST_CUSTNO, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 107259      (CONTRA_ACCNO, VALUEDATE, TR_SP_05, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 107260     (CONTRA_ACCNO, TR_SP_05, BUSINESSNO_TRANS, AMOUNT, ACC_ACCNO, AMOUNTORIG, TR_SP_01, CUST_CUSTNO, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 107261             (CONTRA_ACCNO, TR_SP_05, BUSINESSNO_TRANS, ACC_ACCNO, AMOUNTORIG, TR_SP_01, CUST_CUSTNO, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
# 107262                 (CONTRA_ACCNO, TR_SP_05, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, TR_SP_02, CONTRA_NAME, REASON2)
#
#                     consequents  antecedent support  consequent support  \
# 0                   (VALUEDATE)            0.999998            1.000000
# 1                   (VALUEDATE)            0.999998            1.000000
# 2                   (VALUEDATE)            0.999995            1.000000
# 3                   (VALUEDATE)            0.999998            1.000000
# 4                   (VALUEDATE)            0.999995            1.000000
# ...                         ...                 ...                 ...
# 107258                 (AMOUNT)            0.990008            0.991379
# 107259             (AMOUNTORIG)            0.990008            0.991379
# 107260              (VALUEDATE)            0.990008            1.000000
# 107261      (VALUEDATE, AMOUNT)            0.990008            0.991379
# 107262  (VALUEDATE, AMOUNTORIG)            0.990008            0.991379
#
#          support  confidence      lift  leverage  conviction  zhangs_metric
# 0       0.999998         1.0  1.000000  0.000000         inf       0.000000
# 1       0.999998         1.0  1.000000  0.000000         inf       0.000000
# 2       0.999995         1.0  1.000000  0.000000         inf       0.000000
# 3       0.999998         1.0  1.000000  0.000000         inf       0.000000
# 4       0.999995         1.0  1.000000  0.000000         inf       0.000000
# ...          ...         ...       ...       ...         ...            ...
# 107258  0.990008         1.0  1.008696  0.008535         inf       0.862792
# 107259  0.990008         1.0  1.008696  0.008535         inf       0.862792
# 107260  0.990008         1.0  1.000000  0.000000         inf       0.000000
# 107261  0.990008         1.0  1.008696  0.008535         inf       0.862792
# 107262  0.990008         1.0  1.008696  0.008535         inf       0.862792
#
# [107263 rows x 10 columns]

# %%
#  filter rules by the zhangs metric >0

filtered_rules = rules[rules['zhangs_metric'] > 1]
filtered_rules
# Out:
#                                     antecedents  \
# 511                           (ACC_CURRENCYISO)
# 512                               (FK_CURRENCY)
# 514                (ACC_CURRENCYISO, VALUEDATE)
# 516                    (VALUEDATE, FK_CURRENCY)
# 517                           (ACC_CURRENCYISO)
# 518                               (FK_CURRENCY)
# 33535                                  (AMOUNT)
# 33536                              (AMOUNTORIG)
# 33538                       (AMOUNT, VALUEDATE)
# 33540                   (VALUEDATE, AMOUNTORIG)
# 33541                                  (AMOUNT)
# 33542                              (AMOUNTORIG)
# 37650                 (ACC_CURRENCYISO, AMOUNT)
# 37651             (ACC_CURRENCYISO, AMOUNTORIG)
# 37652                     (FK_CURRENCY, AMOUNT)
# 37653                 (FK_CURRENCY, AMOUNTORIG)
# 37659  (ACC_CURRENCYISO, VALUEDATE, AMOUNTORIG)
# 37660      (ACC_CURRENCYISO, VALUEDATE, AMOUNT)
# 37664      (VALUEDATE, FK_CURRENCY, AMOUNTORIG)
# 37665          (VALUEDATE, AMOUNT, FK_CURRENCY)
# 37667             (ACC_CURRENCYISO, AMOUNTORIG)
# 37668                 (ACC_CURRENCYISO, AMOUNT)
# 37669                 (FK_CURRENCY, AMOUNTORIG)
# 37670                     (FK_CURRENCY, AMOUNT)
#
#                                     consequents  antecedent support  \
# 511                               (FK_CURRENCY)            0.999838
# 512                           (ACC_CURRENCYISO)            0.999838
# 514                               (FK_CURRENCY)            0.999838
# 516                           (ACC_CURRENCYISO)            0.999838
# 517                    (VALUEDATE, FK_CURRENCY)            0.999838
# 518                (ACC_CURRENCYISO, VALUEDATE)            0.999838
# 33535                              (AMOUNTORIG)            0.991379
# 33536                                  (AMOUNT)            0.991379
# 33538                              (AMOUNTORIG)            0.991379
# 33540                                  (AMOUNT)            0.991379
# 33541                   (VALUEDATE, AMOUNTORIG)            0.991379
# 33542                       (AMOUNT, VALUEDATE)            0.991379
# 37650                 (FK_CURRENCY, AMOUNTORIG)            0.991217
# 37651                     (FK_CURRENCY, AMOUNT)            0.991217
# 37652             (ACC_CURRENCYISO, AMOUNTORIG)            0.991217
# 37653                 (ACC_CURRENCYISO, AMOUNT)            0.991217
# 37659                     (FK_CURRENCY, AMOUNT)            0.991217
# 37660                 (FK_CURRENCY, AMOUNTORIG)            0.991217
# 37664                 (ACC_CURRENCYISO, AMOUNT)            0.991217
# 37665             (ACC_CURRENCYISO, AMOUNTORIG)            0.991217
# 37667          (VALUEDATE, AMOUNT, FK_CURRENCY)            0.991217
# 37668      (VALUEDATE, FK_CURRENCY, AMOUNTORIG)            0.991217
# 37669      (ACC_CURRENCYISO, VALUEDATE, AMOUNT)            0.991217
# 37670  (ACC_CURRENCYISO, VALUEDATE, AMOUNTORIG)            0.991217
#
#        consequent support   support  confidence      lift  leverage  \
# 511              0.999838  0.999838         1.0  1.000162  0.000162
# 512              0.999838  0.999838         1.0  1.000162  0.000162
# 514              0.999838  0.999838         1.0  1.000162  0.000162
# 516              0.999838  0.999838         1.0  1.000162  0.000162
# 517              0.999838  0.999838         1.0  1.000162  0.000162
# 518              0.999838  0.999838         1.0  1.000162  0.000162
# 33535            0.991379  0.991379         1.0  1.008696  0.008547
# 33536            0.991379  0.991379         1.0  1.008696  0.008547
# 33538            0.991379  0.991379         1.0  1.008696  0.008547
# 33540            0.991379  0.991379         1.0  1.008696  0.008547
# 33541            0.991379  0.991379         1.0  1.008696  0.008547
# 33542            0.991379  0.991379         1.0  1.008696  0.008547
# 37650            0.991217  0.991217         1.0  1.008861  0.008706
# 37651            0.991217  0.991217         1.0  1.008861  0.008706
# 37652            0.991217  0.991217         1.0  1.008861  0.008706
# 37653            0.991217  0.991217         1.0  1.008861  0.008706
# 37659            0.991217  0.991217         1.0  1.008861  0.008706
# 37660            0.991217  0.991217         1.0  1.008861  0.008706
# 37664            0.991217  0.991217         1.0  1.008861  0.008706
# 37665            0.991217  0.991217         1.0  1.008861  0.008706
# 37667            0.991217  0.991217         1.0  1.008861  0.008706
# 37668            0.991217  0.991217         1.0  1.008861  0.008706
# 37669            0.991217  0.991217         1.0  1.008861  0.008706
# 37670            0.991217  0.991217         1.0  1.008861  0.008706
#
#        conviction  zhangs_metric
# 511           inf            1.0
# 512           inf            1.0
# 514           inf            1.0
# 516           inf            1.0
# 517           inf            1.0
# 518           inf            1.0
# 33535         inf            1.0
# 33536         inf            1.0
# 33538         inf            1.0
# 33540         inf            1.0
# 33541         inf            1.0
# 33542         inf            1.0
# 37650         inf            1.0
# 37651         inf            1.0
# 37652         inf            1.0
# 37653         inf            1.0
# 37659         inf            1.0
# 37660         inf            1.0
# 37664         inf            1.0
# 37665         inf            1.0
# 37667         inf            1.0
# 37668         inf            1.0
# 37669         inf            1.0
# 37670         inf            1.0

# %% [markdown]
# **Convert the data format from numeric to bolean**

# %%
# Convert the DataFrame to a transaction DataFrame
transaction_df = filtered_data.astype(bool)

# %%
transaction_df
# Out:
#          CUST_CUSTNO  ACC_BUSINESSTYPE  ACC_ACCNO  ACC_BUSINESSNO  \
# 907             True             False       True           False
# 1110            True             False       True           False
# 1482            True             False       True           False
# 1716            True             False       True           False
# 1741            True             False       True           False
# ...              ...               ...        ...             ...
# 1030184         True             False       True           False
# 1030228         True             False       True           False
# 1030686         True             False       True           False
# 1030838         True             False       True           False
# 1030900         True             False       True           False
#
#          ACC_CURRENCYISO  BUSINESSNO_TRANS  FK_CURRENCY  AMOUNT  AMOUNTORIG  \
# 907                 True              True         True    True        True
# 1110                True              True         True    True        True
# 1482                True              True         True    True        True
# 1716                True              True         True    True        True
# 1741                True              True         True    True        True
# ...                  ...               ...          ...     ...         ...
# 1030184             True              True         True    True        True
# 1030228             True              True         True    True        True
# 1030686             True              True         True    True        True
# 1030838             True              True         True    True        True
# 1030900             True              True         True    True        True
#
#          BRANCH_OFFICE  ...  REASON1  REASON2  TR_FLAG_01  \
# 907              False  ...     True     True       False
# 1110             False  ...     True     True       False
# 1482             False  ...     True     True       False
# 1716             False  ...     True     True       False
# 1741             False  ...     True     True       False
# ...                ...  ...      ...      ...         ...
# 1030184          False  ...     True     True       False
# 1030228          False  ...     True     True       False
# 1030686          False  ...     True     True       False
# 1030838           True  ...     True     True       False
# 1030900           True  ...     True     True       False
#
#          ANALYTICAL_TRANS_CODE  TR_SP_01  TR_SP_02  TR_SP_03  TR_SP_04  \
# 907                      False      True      True      True     False
# 1110                      True      True      True      True     False
# 1482                     False      True      True      True     False
# 1716                      True      True      True      True      True
# 1741                     False      True      True      True     False
# ...                        ...       ...       ...       ...       ...
# 1030184                   True      True      True      True     False
# 1030228                  False      True      True      True     False
# 1030686                  False      True      True      True     False
# 1030838                   True      True      True      True     False
# 1030900                   True      True      True      True     False
#
#          TR_SP_05  VALUEDATE
# 907          True       True
# 1110         True       True
# 1482         True       True
# 1716         True       True
# 1741         True       True
# ...           ...        ...
# 1030184      True       True
# 1030228      True       True
# 1030686      True       True
# 1030838      True       True
# 1030900      True       True
#
# [420137 rows x 24 columns]

# %%
# Apply the FP-growth algorithm
fpgrowth_results = fpgrowth(transaction_df, min_support=0.01, use_colnames=True)

# %%
fpgrowth_results
# Out:
#           support  \
# 0        1.000000
# 1        0.999998
# 2        0.999998
# 3        0.999998
# 4        0.999998
# ...           ...
# 1179642  0.013665
# 1179643  0.013665
# 1179644  0.013665
# 1179645  0.013665
# 1179646  0.013665
#
#                                                                                                                                                                                                                                                          itemsets
# 0                                                                                                                                                                                                                                                     (VALUEDATE)
# 1                                                                                                                                                                                                                                                      (TR_SP_05)
# 2                                                                                                                                                                                                                                                  (CONTRA_ACCNO)
# 3                                                                                                                                                                                                                                                       (REASON1)
# 4                                                                                                                                                                                                                                                      (TR_SP_01)
# ...                                                                                                                                                                                                                                                           ...
# 1179642                   (TR_SP_03, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179643               (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179644            (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179645            (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
# 1179646  (TR_SP_03, ACC_CURRENCYISO, BRANCH_OFFICE, FK_CURRENCY, VALUEDATE, REASON2, ANALYTICAL_TRANS_CODE, CONTRA_ACCNO, TR_SP_05, TR_SP_04, AMOUNTORIG, TR_SP_02, CONTRA_ZIP, BUSINESSNO_TRANS, ACC_ACCNO, CUST_CUSTNO, TR_SP_01, AMOUNT, REASON1, CONTRA_NAME)
#
# [1179647 rows x 2 columns]
